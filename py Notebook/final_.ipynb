# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import plotly
import plotly.plotly as py
import plotly.figure_factory as ff
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import tools
% matplotlib inline

# %%
pd.set_option('display.max_rows', 500)

# %%
sns.set_context('talk')
sns.set_style(style='darkgrid')

# %%
athletes = pd.read_csv('athlete_events.csv')
noc = pd.read_csv('noc_regions.csv')

# %%
df = athletes.merge(noc, on='NOC')

# %%
df.head(3)
# Out:
#     ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0    1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1    2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2  602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
#
#    Year  Season       City       Sport                         Event Medal  \
# 0  1992  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  2012  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
# 2  2000  Summer     Sydney      Boxing     Boxing Men's Middleweight   NaN
#
#   region notes
# 0  China   NaN
# 1  China   NaN
# 2  China   NaN

# %%
## Medals won by USA in 2016 
## To ensure medals won for team games are only counted as 1, groupby Sport, Event and Medal and then drop the size column
df1 = df[(df.NOC=='USA') & (df.Year==2016)].groupby(['Event', 'Medal']).size().reset_index()
df1.drop(columns=0, inplace=True)
print('Medals won by the US in the 2016 Summer Olympics: ' + str(len(df1)))
df1
# Out:
# Medals won by the US in the 2016 Summer Olympics: 121
#                                                Event   Medal
# 0                           Archery Men's Individual  Bronze
# 1                                 Archery Men's Team  Silver
# 2                       Athletics Men's 1,500 metres    Gold
# 3                         Athletics Men's 100 metres  Silver
# 4          Athletics Men's 3,000 metres Steeplechase  Silver
# 5               Athletics Men's 4 x 400 metres Relay    Gold
# 6                         Athletics Men's 400 metres  Bronze
# 7                 Athletics Men's 400 metres Hurdles    Gold
# 8                       Athletics Men's 5,000 metres  Silver
# 9                         Athletics Men's 800 metres  Bronze
# 10                         Athletics Men's Decathlon    Gold
# 11                         Athletics Men's Long Jump    Gold
# 12                          Athletics Men's Marathon  Bronze
# 13                        Athletics Men's Pole Vault  Bronze
# 14                          Athletics Men's Shot Put    Gold
# 15                          Athletics Men's Shot Put  Silver
# 16                       Athletics Men's Triple Jump    Gold
# 17                       Athletics Men's Triple Jump  Silver
# 18                    Athletics Women's 1,500 metres  Bronze
# 19                      Athletics Women's 100 metres  Silver
# 20              Athletics Women's 100 metres Hurdles  Bronze
# 21              Athletics Women's 100 metres Hurdles    Gold
# 22              Athletics Women's 100 metres Hurdles  Silver
# 23                      Athletics Women's 200 metres  Bronze
# 24       Athletics Women's 3,000 metres Steeplechase  Bronze
# 25            Athletics Women's 4 x 100 metres Relay    Gold
# 26            Athletics Women's 4 x 400 metres Relay    Gold
# 27                      Athletics Women's 400 metres  Silver
# 28              Athletics Women's 400 metres Hurdles  Bronze
# 29              Athletics Women's 400 metres Hurdles    Gold
# 30                       Athletics Women's Long Jump    Gold
# 31                       Athletics Women's Long Jump  Silver
# 32                      Athletics Women's Pole Vault  Silver
# 33                        Athletics Women's Shot Put    Gold
# 34                       Basketball Men's Basketball    Gold
# 35                     Basketball Women's Basketball    Gold
# 36         Beach Volleyball Women's Beach Volleyball  Bronze
# 37                         Boxing Men's Bantamweight  Silver
# 38                      Boxing Men's Light-Flyweight  Bronze
# 39                       Boxing Women's Middleweight    Gold
# 40                                 Cycling Men's BMX    Gold
# 41                               Cycling Women's BMX  Silver
# 42             Cycling Women's Individual Time Trial    Gold
# 43                            Cycling Women's Omnium  Silver
# 44                      Cycling Women's Team Pursuit  Silver
# 45                             Diving Men's Platform  Bronze
# 46                Diving Men's Synchronized Platform  Silver
# 47             Diving Men's Synchronized Springboard  Silver
# 48                Equestrianism Mixed Dressage, Team  Bronze
# 49                 Equestrianism Mixed Jumping, Team  Silver
# 50   Equestrianism Mixed Three-Day Event, Individual  Bronze
# 51                    Fencing Men's Foil, Individual  Silver
# 52                          Fencing Men's Foil, Team  Bronze
# 53                   Fencing Men's Sabre, Individual  Silver
# 54                       Fencing Women's Sabre, Team  Bronze
# 55                             Golf Men's Individual  Bronze
# 56                   Gymnastics Men's Horizontal Bar  Silver
# 57                    Gymnastics Men's Parallel Bars  Silver
# 58                  Gymnastics Men's Pommelled Horse  Bronze
# 59                   Gymnastics Women's Balance Beam  Bronze
# 60                   Gymnastics Women's Balance Beam  Silver
# 61                 Gymnastics Women's Floor Exercise    Gold
# 62                 Gymnastics Women's Floor Exercise  Silver
# 63                    Gymnastics Women's Horse Vault    Gold
# 64          Gymnastics Women's Individual All-Around    Gold
# 65          Gymnastics Women's Individual All-Around  Silver
# 66                Gymnastics Women's Team All-Around    Gold
# 67                    Gymnastics Women's Uneven Bars  Silver
# 68                      Judo Men's Half-Middleweight  Silver
# 69                     Judo Women's Half-Heavyweight    Gold
# 70                       Rowing Women's Coxed Eights    Gold
# 71                      Rowing Women's Single Sculls  Silver
# 72       Sailing Men's One Person Heavyweight Dinghy  Bronze
# 73             Shooting Women's Air Rifle, 10 metres    Gold
# 74                            Shooting Women's Skeet  Bronze
# 75                             Shooting Women's Trap  Bronze
# 76             Swimming Men's 1,500 metres Freestyle  Silver
# 77              Swimming Men's 100 metres Backstroke  Bronze
# 78              Swimming Men's 100 metres Backstroke    Gold
# 79            Swimming Men's 100 metres Breaststroke  Bronze
# 80               Swimming Men's 100 metres Butterfly  Silver
# 81               Swimming Men's 100 metres Freestyle  Bronze
# 82              Swimming Men's 200 metres Backstroke    Gold
# 83            Swimming Men's 200 metres Breaststroke  Silver
# 84               Swimming Men's 200 metres Butterfly    Gold
# 85               Swimming Men's 200 metres Freestyle  Bronze
# 86       Swimming Men's 200 metres Individual Medley    Gold
# 87     Swimming Men's 4 x 100 metres Freestyle Relay    Gold
# 88        Swimming Men's 4 x 100 metres Medley Relay    Gold
# 89     Swimming Men's 4 x 200 metres Freestyle Relay    Gold
# 90       Swimming Men's 400 metres Individual Medley  Silver
# 91                Swimming Men's 50 metres Freestyle  Bronze
# 92                Swimming Men's 50 metres Freestyle    Gold
# 93            Swimming Women's 100 metres Backstroke  Silver
# 94          Swimming Women's 100 metres Breaststroke  Bronze
# 95          Swimming Women's 100 metres Breaststroke    Gold
# 96             Swimming Women's 100 metres Butterfly  Bronze
# 97             Swimming Women's 100 metres Freestyle    Gold
# 98            Swimming Women's 200 metres Backstroke    Gold
# 99             Swimming Women's 200 metres Freestyle    Gold
# 100    Swimming Women's 200 metres Individual Medley  Bronze
# 101  Swimming Women's 4 x 100 metres Freestyle Relay  Silver
# 102     Swimming Women's 4 x 100 metres Medley Relay    Gold
# 103  Swimming Women's 4 x 200 metres Freestyle Relay    Gold
# 104            Swimming Women's 400 metres Freestyle  Bronze
# 105            Swimming Women's 400 metres Freestyle    Gold
# 106    Swimming Women's 400 metres Individual Medley  Silver
# 107             Swimming Women's 50 metres Freestyle  Silver
# 108            Swimming Women's 800 metres Freestyle    Gold
# 109                    Taekwondo Women's Heavyweight  Bronze
# 110                             Tennis Men's Doubles  Bronze
# 111                             Tennis Mixed Doubles    Gold
# 112                             Tennis Mixed Doubles  Silver
# 113               Triathlon Women's Olympic Distance    Gold
# 114                      Volleyball Men's Volleyball  Bronze
# 115                    Volleyball Women's Volleyball  Bronze
# 116                    Water Polo Women's Water Polo    Gold
# 117          Weightlifting Women's Super-Heavyweight  Bronze
# 118           Wrestling Men's Heavyweight, Freestyle    Gold
# 119     Wrestling Men's Light-Heavyweight, Freestyle  Bronze
# 120       Wrestling Women's Featherweight, Freestyle    Gold

# %% [markdown]
# ## A history of participation in the Summer Olympics

# %%
def regions(x):
    region_list = x.NOC.unique()
    return(len(region_list))

# %%
df2 = df[(df.Season=='Summer')].groupby('Year').apply(lambda x: regions(x)).reset_index().rename(columns ={0:'Countries'})

# %%
dataformat = {'x':[1896, 1904, 1948, 1952, 1976, 1980, 2016], 'y':[12, 15, 58, 68, 91, 80, 206], 
                         'text':['1896<br>12 participting NOCs', '1904<br>Out:<br>Russia<br>Japan', 
                                 '1948<br>In:<br>Iran<br>Venezuela<br>Out:<br>Germany<br>Japan', 
                                 '1952<br>In:<br>USSR', '1976<br>Out:<br>Egypt<br>Nigeria<br>Kenya',
                                 '1980<br>Out:<br>United States<br>Japan<br>Canada', 
                                 '2016<br>206 participating NOCs']}
df_format = pd.DataFrame(data = dataformat)

# %%
init_notebook_mode(connected=True)
trace0 = go.Scatter(x=df2.Year, y=df2.Countries, hoverinfo='skip', mode='lines', showlegend=False, 
                    marker = dict(color = 'rgb(17, 157, 255)'), line=dict(width=4))
trace1 = go.Scatter(x=[1936, 1948], y=[49, 58], hoverinfo='skip', mode = 'lines', showlegend=False, 
                    marker = dict(color = 'rgba(255, 0, 0, .9)'), line=dict(width=4))
trace2 = go.Scatter(x=df_format.x, y=df_format.y, text=df_format.text, hoverinfo='text', mode = 'lines', showlegend=False, 
                    opacity=0)

layout0 = go.Layout(
    title='Participation in Summer Olympics over the years', titlefont=dict(family='Arial', size=25),
    xaxis=dict(title='Year', titlefont=dict(size=25), showticklabels=True, tickfont=dict(size=20, color='black')),
    yaxis=dict(title='No. of NOCs', titlefont=dict(size=25), showticklabels=True, 
               tickfont=dict(size=20, color='black')), 
    annotations=[
        dict(x=1944, y=56, xref='x', yref='y', text='World War II', ax=1, ay=-60,
                      font=dict(size=15, color='#34495e'), align='center', arrowwidth=2, bordercolor='red',
                      borderwidth=0, borderpad=0, bgcolor='#fbfcfc', opacity=0.8)],
)

fig = go.Figure(data=[trace0, trace1, trace2], layout=layout0)
plotly.offline.iplot(fig, filename='Olympics1')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="dae3e737-d8d6-43cc-9a3a-e8f6301c52d9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'dae3e737-d8d6-43cc-9a3a-e8f6301c52d9',
#             [{"hoverinfo": "skip", "line": {"width": 4}, "marker": {"color": "rgb(17, 157, 255)"}, "mode": "lines", "showlegend": false, "x": [1896.0, 1900.0, 1904.0, 1906.0, 1908.0, 1912.0, 1920.0, 1924.0, 1928.0, 1932.0, 1936.0, 1948.0, 1952.0, 1956.0, 1960.0, 1964.0, 1968.0, 1972.0, 1976.0, 1980.0, 1984.0, 1988.0, 1992.0, 1996.0, 2000.0, 2004.0, 2008.0, 2012.0, 2016.0], "y": [12.0, 31.0, 15.0, 21.0, 22.0, 29.0, 29.0, 45.0, 46.0, 47.0, 49.0, 58.0, 68.0, 71.0, 83.0, 93.0, 111.0, 120.0, 91.0, 80.0, 139.0, 158.0, 168.0, 196.0, 199.0, 200.0, 203.0, 204.0, 206.0], "type": "scatter", "uid": "a43edf30-a188-11e8-9568-d0577b2f97ce"}, {"hoverinfo": "skip", "line": {"width": 4}, "marker": {"color": "rgba(255, 0, 0, .9)"}, "mode": "lines", "showlegend": false, "x": [1936, 1948], "y": [49, 58], "type": "scatter", "uid": "a43ef1f4-a188-11e8-b619-d0577b2f97ce"}, {"hoverinfo": "text", "mode": "lines", "opacity": 0, "showlegend": false, "text": ["1896<br>12 participting NOCs", "1904<br>Out:<br>Russia<br>Japan", "1948<br>In:<br>Iran<br>Venezuela<br>Out:<br>Germany<br>Japan", "1952<br>In:<br>USSR", "1976<br>Out:<br>Egypt<br>Nigeria<br>Kenya", "1980<br>Out:<br>United States<br>Japan<br>Canada", "2016<br>206 participating NOCs"], "x": [1896.0, 1904.0, 1948.0, 1952.0, 1976.0, 1980.0, 2016.0], "y": [12.0, 15.0, 58.0, 68.0, 91.0, 80.0, 206.0], "type": "scatter", "uid": "a43ef1f5-a188-11e8-89fa-d0577b2f97ce"}],
#             {"annotations": [{"align": "center", "arrowwidth": 2, "ax": 1, "ay": -60, "bgcolor": "#fbfcfc", "bordercolor": "red", "borderpad": 0, "borderwidth": 0, "font": {"color": "#34495e", "size": 15}, "opacity": 0.8, "text": "World War II", "x": 1944, "xref": "x", "y": 56, "yref": "y"}], "title": "Participation in Summer Olympics over the years", "titlefont": {"family": "Arial", "size": 25}, "xaxis": {"showticklabels": true, "tickfont": {"color": "black", "size": 20}, "title": "Year", "titlefont": {"size": 25}}, "yaxis": {"showticklabels": true, "tickfont": {"color": "black", "size": 20}, "title": "No. of NOCs", "titlefont": {"size": 25}}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('dae3e737-d8d6-43cc-9a3a-e8f6301c52d9',{});}).then(function(){Plotly.animate('dae3e737-d8d6-43cc-9a3a-e8f6301c52d9');})
#         });</script>

# %% [markdown]
# NOC - National Olympic Commitee <br>
# 1896 - First Olympic Games with 12 participating countries <br>
# 1904 - Olympic games held at St. Louis. Logistics caused a lot of countries to stay away. Most participants were American. <br>
# 1940 & 1944 games cancelled due to World War II <br>
# 1948 - Largest no. of participants since the inception of the Summer Olympics. 14 countries made their first appearance.
#        Iran, Korea, Venezuela, Singapore etc. participate for the first time. Germany, Japan and the Soviet Union did not              participate <br>
# 1952 - USSR participates for the first time and finishes second <br>
# 1976 - 29 countries, mostly African boycotted the games as a protest against New Zealand who had recently toured the apartheid run South Africa <br>
# 1980 - 66 countries boycotted the games to protest the Soviet invasion of Afghanistan <br>
# 2008 - More than 200 participating committees

# %% [markdown]
# ## Top performers in the summer games vs the winter games
# ### Top performers measured by total tally of medals and also by average medals won per Olympic games

# %%
def medals(x):
    return((len(x.Medal.unique())))

# %%
## Dictionary of NOCs and regions
df_NOC_region = df[['NOC', 'region']].drop_duplicates().dropna()

# %%
## Top 10 performers in Summer Olympics vs Winter Olympics by medal tally
df_event_medals = df[(df.Season=='Summer')&(df.Medal.notnull())].groupby(['NOC', 'Year', 'Event']).apply(
    lambda x: medals(x)).reset_index()
df_medals_summer0 = df_event_medals.groupby(['NOC'])[0].sum().sort_values(ascending=False).head(10).reset_index().rename(
    columns={0:'medal_tally'})
df_medals_summer = df_medals_summer0.merge(df_NOC_region, on='NOC', how='left')

df_event_medals1 = df[(df.Season=='Winter')&(df.Medal.notnull())].groupby(['NOC', 'Year', 'Event']).apply(
    lambda x: medals(x)).reset_index()
df_medals_winter0 = df_event_medals1.groupby(['NOC'])[0].sum().sort_values(ascending=False).head(10).reset_index().rename(
    columns={0:'medal_tally'})
df_medals_winter = df_medals_winter0.merge(df_NOC_region, on='NOC', how='left')

# %%
## Top 10 performers in Summer Olympics vs Winter Olympics by avg medals per Olympic games
df_summer_games = df_event_medals.groupby(['NOC'])['Year'].apply(lambda x: len(x.unique())).reset_index().rename(columns=
    {'Year':'no_of_olympics'})
df_avg_summer = df_summer_games.merge(df_medals_summer, on='NOC', how='inner')
df_avg_summer['avg_medals'] = (df_avg_summer['medal_tally']) / (df_avg_summer['no_of_olympics'])
df_avg_summer.sort_values('avg_medals', ascending=False, inplace=True)

df_winter_games = df_event_medals1.groupby(['NOC'])['Year'].apply(lambda x: len(x.unique())).reset_index().rename(columns=
    {'Year':'no_of_olympics'})
df_avg_winter = df_winter_games.merge(df_medals_winter, on='NOC', how='inner')
df_avg_winter['avg_medals'] = (df_avg_winter['medal_tally']) / (df_avg_winter['no_of_olympics'])
df_avg_winter.sort_values('avg_medals', ascending=False, inplace=True)

# %%
init_notebook_mode(connected=True)

data1 = go.Bar(x=df_medals_summer.NOC, y=df_medals_summer.medal_tally, text=df_medals_summer.region, hoverinfo='text', 
               name='Summer Games', marker=dict(color='#ff8000'))
data2 = go.Bar(x=df_medals_winter.NOC, y=df_medals_winter.medal_tally, text=df_medals_winter.region, hoverinfo='text', 
               name='Winter Games', marker=dict(color='#3399ff'))
data3 = go.Scatter(x=df_avg_summer.NOC, y=df_avg_summer.avg_medals, text=df_avg_summer.region, hoverinfo='text', 
                   mode='lines', marker=dict(color='#ff8000'), showlegend=False)
data4 = go.Scatter(x=df_avg_winter.NOC, y=df_avg_winter.avg_medals, text=df_avg_winter.region, hoverinfo='text', mode='lines', 
                   marker=dict(color='#3399ff'), showlegend=False)

fig1 = tools.make_subplots(rows=2, cols=2, 
                           subplot_titles=('Top 10 NOCs by medal tally', 
                                           'Top 10 NOCs by medal tally', 
                                           'Top 10 NOCs by avg number of medals won', 
                                           'Top 10 NOCs by avg number of medals won'), 
                           vertical_spacing=0.15, horizontal_spacing=0.15)

fig1.append_trace(data1, 1,1)
fig1.append_trace(data2, 1, 2)
fig1.append_trace(data3, 2, 1)
fig1.append_trace(data4, 2, 2)

fig1['layout']['xaxis1'].update(title='NOC')
fig1['layout']['xaxis2'].update(title='NOC')
fig1['layout']['xaxis3'].update(title='NOC')
fig1['layout']['xaxis4'].update(title='NOC')

fig1['layout']['yaxis1'].update(title='Medal count')
fig1['layout']['yaxis2'].update(title='Medal count')
fig1['layout']['yaxis3'].update(title='Avg medals')
fig1['layout']['yaxis4'].update(title='Avg medals')


fig1['layout'].update(height=800, width=1000, 
                      title='Top 10 performers in Summer games vs Winter games', 
                      titlefont=dict(family='Arial', size=20), 
                      xaxis=dict(autorange='reversed'), yaxis=dict(side='right'), 
                      xaxis3=dict(autorange='reversed'), yaxis3=dict(side='right'))

plotly.offline.iplot(fig1, filename='Olympics2')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]  [ (1,2) x2,y2 ]
# [ (2,1) x3,y3 ]  [ (2,2) x4,y4 ]
# C:\Users\vinit\AppData\Local\Programs\Python\Python36\lib\site-packages\plotly\graph_objs\_deprecations.py:318: DeprecationWarning:
#
# plotly.graph_objs.Font is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.layout.Font
#   - plotly.graph_objs.layout.hoverlabel.Font
#   - etc.
# <div id="37dd105c-1f64-4d29-9379-56f077a675b3" style="height: 800px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '37dd105c-1f64-4d29-9379-56f077a675b3',
#             [{"hoverinfo": "text", "marker": {"color": "#ff8000"}, "name": "Summer Games", "text": ["USA", "Russia", "UK", "Germany", "France", "Italy", "China", "Sweden", "Australia", "Hungary"], "x": ["USA", "URS", "GBR", "GER", "FRA", "ITA", "CHN", "SWE", "AUS", "HUN"], "y": [2544.0, 1005.0, 892.0, 776.0, 770.0, 608.0, 542.0, 513.0, 506.0, 504.0], "type": "bar", "uid": "9305baa4-a189-11e8-8f91-d0577b2f97ce", "xaxis": "x", "yaxis": "y"}, {"hoverinfo": "text", "marker": {"color": "#3399ff"}, "name": "Winter Games", "text": ["Norway", "USA", "Germany", "Austria", "Russia", "Canada", "Finland", "Sweden", "Switzerland", "Russia"], "x": ["NOR", "USA", "GER", "AUT", "URS", "CAN", "FIN", "SWE", "SUI", "RUS"], "y": [319.0, 279.0, 228.0, 218.0, 192.0, 170.0, 161.0, 144.0, 137.0, 124.0], "type": "bar", "uid": "930718a6-a189-11e8-b923-d0577b2f97ce", "xaxis": "x2", "yaxis": "y2"}, {"hoverinfo": "text", "marker": {"color": "#ff8000"}, "mode": "lines", "showlegend": false, "text": ["Russia", "USA", "China", "Germany", "UK", "France", "Italy", "Sweden", "Australia", "Hungary"], "x": ["URS", "USA", "CHN", "GER", "GBR", "FRA", "ITA", "SWE", "AUS", "HUN"], "y": [111.66666666666667, 90.85714285714286, 60.22222222222222, 38.8, 30.75862068965517, 26.551724137931036, 22.51851851851852, 19.0, 18.74074074074074, 18.666666666666668], "type": "scatter", "uid": "93089c42-a189-11e8-b457-d0577b2f97ce", "xaxis": "x3", "yaxis": "y3"}, {"hoverinfo": "text", "marker": {"color": "#3399ff"}, "mode": "lines", "showlegend": false, "text": ["Russia", "Russia", "Germany", "Norway", "USA", "Austria", "Canada", "Finland", "Sweden", "Switzerland"], "x": ["URS", "RUS", "GER", "NOR", "USA", "AUT", "CAN", "FIN", "SWE", "SUI"], "y": [21.333333333333332, 20.666666666666668, 16.285714285714285, 14.5, 12.681818181818182, 9.909090909090908, 7.7272727272727275, 7.318181818181818, 6.545454545454546, 6.523809523809524], "type": "scatter", "uid": "930a1fa2-a189-11e8-bbc4-d0577b2f97ce", "xaxis": "x4", "yaxis": "y4"}],
#             {"annotations": [{"font": {"size": 16}, "showarrow": false, "text": "Top 10 NOCs by medal tally", "x": 0.2125, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Top 10 NOCs by medal tally", "x": 0.7875, "xanchor": "center", "xref": "paper", "y": 1.0, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Top 10 NOCs by avg number of medals won", "x": 0.2125, "xanchor": "center", "xref": "paper", "y": 0.425, "yanchor": "bottom", "yref": "paper"}, {"font": {"size": 16}, "showarrow": false, "text": "Top 10 NOCs by avg number of medals won", "x": 0.7875, "xanchor": "center", "xref": "paper", "y": 0.425, "yanchor": "bottom", "yref": "paper"}], "xaxis": {"anchor": "y", "domain": [0.0, 0.425], "title": "NOC", "autorange": "reversed"}, "yaxis": {"anchor": "x", "domain": [0.575, 1.0], "title": "Medal count", "side": "right"}, "xaxis2": {"anchor": "y2", "domain": [0.575, 1.0], "title": "NOC"}, "yaxis2": {"anchor": "x2", "domain": [0.575, 1.0], "title": "Medal count"}, "xaxis3": {"anchor": "y3", "domain": [0.0, 0.425], "title": "NOC", "autorange": "reversed"}, "yaxis3": {"anchor": "x3", "domain": [0.0, 0.425], "title": "Avg medals", "side": "right"}, "xaxis4": {"anchor": "y4", "domain": [0.575, 1.0], "title": "NOC"}, "yaxis4": {"anchor": "x4", "domain": [0.0, 0.425], "title": "Avg medals"}, "titlefont": {"family": "Arial", "size": 20}, "height": 800, "width": 1000, "title": "Top 10 performers in Summer games vs Winter games"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('37dd105c-1f64-4d29-9379-56f077a675b3',{});}).then(function(){Plotly.animate('37dd105c-1f64-4d29-9379-56f077a675b3');})
#         });</script>
